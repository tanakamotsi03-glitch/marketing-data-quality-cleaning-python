# %% [markdown]
# **Data Cleaning **

# %%
import pandas as pd
import numpy as np

# Load the messy data
df = pd.read_csv('marketing_campaign_data_messy.csv')
print(f"Loaded Dataset: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# Loaded Dataset: 2020 rows, 12 columns

# %%
df
# Out:
#      campaign_id             campaign_name           start_date    end_date  \
# 0      CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 1      CMP-00002       Q1_Launch_CMP-00002  2023-05-06 00:00:00  2023-05-12
# 2      CMP-00003       Q3_Winter_CMP-00003  2023-12-13 00:00:00  2023-12-20
# 3      CMP-00004  Q1_BlackFriday_CMP-00004           2023-10-30  2023-11-03
# 4      CMP-00005       Q2_Winter_CMP-00005  2023-04-22 00:00:00  2023-04-23
# ...          ...                       ...                  ...         ...
# 2015   CMP-00400       Q3_Summer_CMP-00400  2023-10-31 00:00:00  2023-11-13
# 2016   CMP-01255       Q4_Summer_CMP-01255  2023-09-01 00:00:00  2023-09-26
# 2017   CMP-01050       Q2_Launch_CMP-01050  2023-02-09 00:00:00  2023-02-21
# 2018   CMP-01118       Q4_Winter_CMP-01118  2023-03-30 00:00:00  2023-04-27
# 2019   CMP-01554       Q4_Launch_CMP-01554  2023-06-26 00:00:00  2023-07-09
#
#          channel  impressions  clicks    spend  conversions  active  clicks  \
# 0         TikTok        16795     197   102.82         20.0    True     NaN
# 1       Facebook         1860      30    24.33          1.0    True     NaN
# 2          Email        77820     843  1323.39         51.0    True     NaN
# 3         TikTok        55886    2019  2180.38        135.0    True     NaN
# 4       Facebook         7265     169   252.44         30.0    True     NaN
# ...          ...          ...     ...      ...          ...     ...     ...
# 2015      TikTok        30592     586   503.95         77.0    True     NaN
# 2016  Google Ads        20097     897  1641.00        162.0    True     NaN
# 2017   Instagram        33254    1117   883.82        214.0    True     NaN
# 2018    Facebook        68728    2960  4198.50        591.0    True     NaN
# 2019       Email        96402    1090  1315.59         66.0    True     NaN
#
#      campaign_tag
# 0              TI
# 1              FA
# 2              EM
# 3              TI
# 4              FA
# ...           ...
# 2015           TI
# 2016           GO
# 2017           IN
# 2018           FA
# 2019           EM
#
# [2020 rows x 12 columns]

# %%
#======================
#Step 1: Header Cleaning
#=======================

print(df.columns.tolist())
df.columns = df.columns.str.strip().str.lower().str.replace(' ','_')
print("Fix Applied")
print(df.columns.tolist())
# Out:
# [' Campaign_ID ', 'Campaign_Name', 'Start_Date', 'End_Date', 'Channel', 'Impressions', 'Clicks ', 'Spend', 'Conversions', 'Active', 'Clicks', 'Campaign_Tag']
# Fix Applied
# ['campaign_id', 'campaign_name', 'start_date', 'end_date', 'channel', 'impressions', 'clicks', 'spend', 'conversions', 'active', 'clicks', 'campaign_tag']

# %%
#=============================================
#Step 2: Type Conversion and Currency Cleaning
#=============================================

dirty_spend_mask = df['spend'].astype(str).str.contains(r'\$')
print(df.loc[dirty_spend_mask,['campaign_id', 'spend']].head(3))
df['spend'] = df['spend'].astype(str).str.replace(r'[^\d.-]','', regex = True)
df['spend'] = pd.to_numeric(df['spend'])
print("Fix Applied")
print(df.loc[dirty_spend_mask,['campaign_id', 'spend']].head(3))
# Out:
#    campaign_id     spend
# 0    CMP-00001   $102.82
# 21   CMP-00022   $2428.4
# 22   CMP-00023  $4726.22
# Fix Applied
#    campaign_id    spend
# 0    CMP-00001   102.82
# 21   CMP-00022  2428.40
# 22   CMP-00023  4726.22

# %%
#=============================================
#Step 3: Categorial Typos (Fuzzy Logic)
#=============================================

print(df['channel'].unique())

cleanup_map = {
    'Facebok': 'Facebook',
    'Insta_gram': 'Instagram',
    'Gogle': 'Google Ads',
    'Tik_Tok': 'TikTok',
    'E-mail': 'Email',
    'N/A': np.nan

}
df['channel'] = df['channel'].replace(cleanup_map)
print("Fix Applied")
print(df['channel'].unique())
# Out:
# ['TikTok' 'Facebook' 'Email' 'Instagram' 'Google Ads' 'E-mail' nan 'Gogle'
#  'Tik_Tok' 'Facebok' 'Insta_gram']
# Fix Applied
# ['TikTok' 'Facebook' 'Email' 'Instagram' 'Google Ads' nan]

# %%
#=============================================
#Step 4: Handling the Mixed Booleans
#=============================================

print(df['active'].unique())

bool_map = {
   'Yes': 'True',
   '0': 'False',
   '1': 'True',
   'No': 'False',
   'Y': 'True',
   1: 'True',
   0: 'False'

}

df['active'] = df['active'].map(bool_map).fillna('False').astype(bool)
print("Fix Applied")
print(df['active'].unique())
# Out:
# [ True]
# Fix Applied
# [ True]

# %%
#=============================================
#Step 5: Date Parsing
#=============================================

print(df['start_date'].dtype)
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['end_date'] = pd.to_datetime(df['end_date'], errors='coerce')

print("Fix Applied")
print(df['start_date'].dtype)
# Out:
# object
# Fix Applied
# datetime64[ns]

# %%
df = df.loc[:, ~df.columns.duplicated()]

# %%
df
# Out:
#      campaign_id             campaign_name start_date   end_date     channel  \
# 0      CMP-00001       Q4_Summer_CMP-00001 2023-11-24 2023-12-13      TikTok
# 1      CMP-00002       Q1_Launch_CMP-00002 2023-05-06 2023-05-12    Facebook
# 2      CMP-00003       Q3_Winter_CMP-00003 2023-12-13 2023-12-20       Email
# 3      CMP-00004  Q1_BlackFriday_CMP-00004        NaT 2023-11-03      TikTok
# 4      CMP-00005       Q2_Winter_CMP-00005 2023-04-22 2023-04-23    Facebook
# ...          ...                       ...        ...        ...         ...
# 2015   CMP-00400       Q3_Summer_CMP-00400 2023-10-31 2023-11-13      TikTok
# 2016   CMP-01255       Q4_Summer_CMP-01255 2023-09-01 2023-09-26  Google Ads
# 2017   CMP-01050       Q2_Launch_CMP-01050 2023-02-09 2023-02-21   Instagram
# 2018   CMP-01118       Q4_Winter_CMP-01118 2023-03-30 2023-04-27    Facebook
# 2019   CMP-01554       Q4_Launch_CMP-01554 2023-06-26 2023-07-09       Email
#
#       impressions  clicks    spend  conversions  active campaign_tag
# 0           16795     197   102.82         20.0    True           TI
# 1            1860      30    24.33          1.0    True           FA
# 2           77820     843  1323.39         51.0    True           EM
# 3           55886    2019  2180.38        135.0    True           TI
# 4            7265     169   252.44         30.0    True           FA
# ...           ...     ...      ...          ...     ...          ...
# 2015        30592     586   503.95         77.0    True           TI
# 2016        20097     897  1641.00        162.0    True           GO
# 2017        33254    1117   883.82        214.0    True           IN
# 2018        68728    2960  4198.50        591.0    True           FA
# 2019        96402    1090  1315.59         66.0    True           EM
#
# [2020 rows x 11 columns]

# %%
#=============================================
#Step 6: Logical Integrity (Clicks vs Impressions)
#=============================================

impossible_mask = df['clicks'] > df['impressions']
print(df.loc[impossible_mask, ['campaign_id', 'impressions', 'clicks']].head(3))
# Out:
# Empty DataFrame
# Columns: [campaign_id, impressions, clicks]
# Index: []

# %%
#=============================================
#Step 7: Logical Integrity (Time Travel)
#=============================================

time_travel_mask = df['end_date'] < df['start_date']
print(df.loc[time_travel_mask, ['campaign_id', 'start_date','end_date']].head(3))

#campaigns usually last 30 days

df.loc[time_travel_mask, 'end_date'] = df.loc[time_travel_mask ,'start_date'] + pd.Timedelta(days=30)
print("Fix Applied")
print(df.loc[time_travel_mask, ['campaign_id', 'start_date','end_date']].head(3))
# Out:
#    campaign_id start_date   end_date
# 23   CMP-00024 2023-05-06 2023-05-01
# 54   CMP-00055 2023-09-01 2023-08-27
# 71   CMP-00072 2023-02-01 2023-01-27
# Fix Applied
#    campaign_id start_date   end_date
# 23   CMP-00024 2023-05-06 2023-06-05
# 54   CMP-00055 2023-09-01 2023-10-01
# 71   CMP-00072 2023-02-01 2023-03-03

# %%
#=============================================
#Step 8: Handling Outliers (winsorizing)
#=============================================

Q1 = df['spend'].quantile(0.25)
Q3 = df['spend'].quantile(0.75)

IQR = Q3 - Q1
upper_limit = Q3 + (3 * IQR)
outlier_mask = df['spend'] > upper_limit
print(df.loc[outlier_mask, ['campaign_id', 'spend']].head(3))

print("Fix Applied")
df.loc[outlier_mask, 'spend'] = upper_limit
print(df.loc[outlier_mask, ['campaign_id', 'spend']].head(3))
# Out:
#      campaign_id      spend
# 789    CMP-00790  500000.00
# 1443   CMP-01444    8921.51
# 1460   CMP-01461  500000.00
# Fix Applied
#      campaign_id      spend
# 789    CMP-00790  8603.5375
# 1443   CMP-01444  8603.5375
# 1460   CMP-01461  8603.5375

# %%
#=============================================
#Step 9: String Parsing (Feature Extraction)
#=============================================

print(df['campaign_name'].head(3))
df['season'] = df['campaign_name'].str.extract(r'Q\d_([^_]+)_')
print("Fix Applied")
print(df[['campaign_name', 'season']].head(3))
# Out:
# 0    Q4_Summer_CMP-00001
# 1    Q1_Launch_CMP-00002
# 2    Q3_Winter_CMP-00003
# Name: campaign_name, dtype: object
# Fix Applied
#          campaign_name  season
# 0  Q4_Summer_CMP-00001  Summer
# 1  Q1_Launch_CMP-00002  Launch
# 2  Q3_Winter_CMP-00003  Winter
